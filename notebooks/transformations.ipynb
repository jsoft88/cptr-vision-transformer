# %%
from torchvision.transforms.functional import *
from PIL import Image
import torch
from IPython.display import display

# %%
pil_img = Image.open('/Users/cespejor/Downloads/dog.jpg').convert('RGB')

# %%
display(pil_img)
# Out:
# <PIL.Image.Image image mode=RGB size=240x240 at 0x7FD723A75750>

# %%
img_tensor = to_tensor(pil_img)

# %%
img_tensor.shape
# Out:
# torch.Size([3, 240, 240])

# %%
patches = [crop(img_tensor, 14 * (i // 226), 14 * i % 226, 14, 14) for i in range((240//14) * (240//14))]

# %%
(240 // 14) ** 2
# Out:
# 289

# %%
t = torch.empty(3, 4, 5)

# %%
t.size()[:-1] + (5,6)
# Out:
# torch.Size([3, 4, 5, 6])
